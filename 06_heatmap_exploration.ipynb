# %% [markdown]
# ## Import Libraries for Heatmap generation

# %% [markdown]
# #### z-scores: blue=low, white=mean, red=high.

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import numpy as np

# %%
rng = np.random.default_rng(seed=42)

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Initialise Data Path

# %%
data_path = 'data/Raw_Data_Batch1_LAB1_CTX2.csv'
counts = pd.read_csv(data_path)
counts = counts.drop(columns=[
                   	"Row",
                    "Column",
                    "Timepoint",
                    "Field",
                    "Object No",
                    "X",
                    "Y",
                    "Bounding Box",
                    "Batch",
                    "Nuclei - Object No in Nuclei_all"
                   ])
# Double check here
cell_line_ids = counts["Cellline ID"]
cell_types = counts["Cell Type"]
print("counts (before): ", counts.shape)
# Out:
# counts (before):  (20682, 1327)

# %%
counts = counts.select_dtypes(include='number')

counts["Cellline ID"] = cell_line_ids
counts["Cell Type"] = cell_types


print("counts (after): ", counts.shape)
cell_line_agg_df = counts.groupby(['Cellline ID', 'Cell Type']).mean()

print("cell_line_agg (before): ", cell_line_agg_df.shape)
cell_line_agg_df = cell_line_agg_df.dropna(axis=1)

print("cell_line_agg (after): ", cell_line_agg_df.shape)
# Out:
# counts (after):  (20682, 1327)
# /tmp/ipykernel_197929/4247022659.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   counts["Cellline ID"] = cell_line_ids
# /tmp/ipykernel_197929/4247022659.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   counts["Cell Type"] = cell_types
# cell_line_agg (before):  (13, 1325)
# cell_line_agg (after):  (13, 1312)

# %%
cell_line_agg_df = cell_line_agg_df.drop(columns=['Position X [Âµm]', 'Position Y [Âµm]'])

# %%
cell_line_agg_df
# Out:
#                        Lysosome Intensity - Nucleus region Mean  \
# Cellline ID Cell Type
# 01-060 C9   PRKN                                    2397.114860
# 09-090 C18  PRKN                                    1946.967211
# 111450-107  Control                                 2515.278619
# 11302-101   Control                                 2809.234488
# 11555-104   SNCA                                    2480.385462
# 11556-110   SNCA                                    1640.041258
# 11557-103   SNCA                                    2354.915873
# 11576-101   LRRK2                                   1470.152495
# 14555-107   LRRK2                                   2378.571557
# 14557-107   LRRK2                                   2296.956521
# KOLF2-1     Control                                 2476.043322
# PK6         PRKN                                    2734.837440
# RM3.5       Control                                 1999.021782
#
# ...

# %%
cell_region_symmetry_lysosome_12_ser_dark = cell_line_agg_df['Lysosome Spatial - Cell region Symmetry 12 SER-Dark']

# %%
cell_region_symmetry_lysosome_12_ser_dark
# Out:
# Cellline ID  Cell Type
# 01-060 C9    PRKN         0.438922
# 09-090 C18   PRKN         0.394421
# 111450-107   Control      0.452086
# 11302-101    Control      0.450256
# 11555-104    SNCA         0.459249
# 11556-110    SNCA         0.388697
# 11557-103    SNCA         0.414969
# 11576-101    LRRK2        0.395280
# 14555-107    LRRK2        0.425826
# 14557-107    LRRK2        0.444547
# KOLF2-1      Control      0.424060
# PK6          PRKN         0.455509
# RM3.5        Control      0.430828
# Name: Lysosome Spatial - Cell region Symmetry 12 SER-Dark, dtype: float64

# %%
cell_region_symmetry_lysosome_13_ser_edge = cell_line_agg_df['Lysosome Spatial - Outer region Symmetry 13 SER-Edge']
cell_region_symmetry_lysosome_13_ser_edge_df = cell_region_symmetry_lysosome_13_ser_edge.reset_index()
cell_lines = cell_region_symmetry_lysosome_13_ser_edge_df['Cellline ID']
cell_types = cell_region_symmetry_lysosome_13_ser_edge_df['Cell Type']

# %%
inner_region_spatial_lysosome_14 = cell_line_agg_df['Lysosome Spatial - Inner region Symmetry 14']
inner_region_spatial_lysosome_14_df = inner_region_spatial_lysosome_14.reset_index()
cell_types = inner_region_spatial_lysosome_14_df['Cell Type']
cell_lines = inner_region_spatial_lysosome_14_df['Cellline ID']

# %%
scaler = StandardScaler()
inner_region_spatial_lysosome_14_df = inner_region_spatial_lysosome_14_df.drop(columns=['Cell Type', 'Cellline ID'])
scaled_data = scaler.fit_transform(inner_region_spatial_lysosome_14_df)
scaled_data = pd.DataFrame(scaled_data)
# scaled_data['Cell line'] = cell_lines

# %%
g = sns.heatmap(
    scaled_data
)
